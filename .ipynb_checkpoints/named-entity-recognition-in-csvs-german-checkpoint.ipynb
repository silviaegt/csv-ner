# %% [markdown]
# # Named entity recognition in CSVs
#
# This notebook uses [Spacy](https://spacy.io/) to perform named-entity recognition on text in specified columns of a CSV file. The notebook adds new columns to the CSV with the identified entities.
# It is 90% based on this wonderful notebook: https://github.com/quinnanya/csv-ner/blob/master/named-entity-recognition-in-csvs.ipynb. Only step 5 is new :)

# %% [markdown]
# ## Step 1. Load core modules

# %%
#os is used to change the directory
import os
#spacy is used for the NER
import spacy
#pandas is used to read, edit, and write tabular data
import pandas as pd

# %% [markdown]
# ## Step 2. Download and load language-specific data
# This notebook was originally created for German text, but you can substitute values in the following two cells with the corresponding ones for [another language that Spacy supports](https://spacy.io/models). Choose the language you'd like, and check the box for "import as module" on the Spacy site to see the values for the language you'd like to use.
#
# For instance, to use Lithuanian, you'd change the first code cell below to: `!python -m spacy download lt_core_news_sm`
#
# and the second one to:
#
# `import lt_core_news_sm
# snlp = spacy.load("import lt_core_news_sm")`
#
# After you've run the first code cell once ever on the computer where you're running this notebook, you can skip it and just run the cell that imports the module. There's no harm in running the first cell again, but it won't do anything.

# %%
#downloads the model for the specified language (German)
# !python -m spacy download de_core_news_md
# Out:
# Collecting de-core-news-md==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_md-3.1.0/de_core_news_md-3.1.0-py3-none-any.whl (47.8 MB)
#      |████████████████████████████████| 47.8 MB 1.1 MB/s
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from de-core-news-md==3.1.0) (3.1.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.0.6)
# Requirement already satisfied: jinja2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (0.7.5)
# Requirement already satisfied: setuptools in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (58.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (20.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (0.6.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.25.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (0.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (4.59.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (0.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (8.0.12)
# Requirement already satisfied: numpy>=1.15.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.20.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.4.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->de-core-news-md==3.1.0) (1.1.1)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/silviaegt/anaconda3/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_md')

# %%
#imports the model as a module
import de_core_news_md
#loads the model as snlp
snlp = spacy.load("de_core_news_md")

# %% [markdown]
# ## Step 3. Specify file directory and file
# Replace `/Users/qad/Documents/netzdg` with the full path to the directory that has your input CSV file. This is also the directory where your output CSV file will be saved.
#
# The syntax for the path is different on Mac and Windows. For instance, the default path to the Documents directory is (substituting your user name on the computer for YOUR-USER-NAME):
#
# - On Mac: '/Users/YOUR-USER-NAME/Documents'
# - On Windows: 'C:\\\Users\\\YOUR-USER-NAME\\\Documents'
#
# Then, replace `netzdg_blog.csv` with the name of a CSV file in the directory you've specified. The first row of the CSV file should be a header (i.e. with the name of each column).

# %%
sourcefiledirectory = '/home/silviaegt/Documents/corpus_de'
#changes the working directory to the directory specified above
os.chdir(sourcefiledirectory)
infilename = 'metadata_de_clean.csv'

# %% [markdown]
# ## Step 4. Reading CSV, performing NER
# This step actually processes your data.
#
# In this example, there are two columns in the source file that contain text where we want to find entities: *text* and *comments*.
#
# The cell below reads in the data from the CSV file you've specified above. It creates two new columns: *ner_text* which includes the entities extracted from the *title_normalized* column (you can change the name).
#
# The `print(df['ner_text'])` command is optional, but are a convenient way for you to get a sense of what the output will be. When the values are printed, each term is surrounded by parentheses (), and all the entities for a given row of the CSV are surrounded by square brackets \[\]. When you *print* the output, multi-word entities are separated by commas within the parentheses (such as: (Europäische, Union)), but when you *write* it to a new CSV file, the parentheses and commas between individual words disappear, and you'll just get a single comma-separated list inside of square brackets, with commas representing individual entities (e.g. \[Uploadfilter, Europäische Union\]).

# %%
#creates pandas dataframe with your specified input file, using the first row as a header
df = pd.read_csv(infilename, header=0)
#creates a new column, ner_text, with entities extracted from a column titled 'text'
df['ner_text'] = df['title_normalized'].astype(str).apply(lambda x: list(snlp(x).ents))
#prints the values from ner_text
print(df['ner_text'])
# Out:
# 0                [(jüdischen), (nationalsozialistischen)]
# 1                                           [(Englische)]
# 2       [(Australian, Reflections, in, a, Mirror, Clou...
# 3                                           [(Deutschen)]
# 4       [(gerbet, han), (Wolframs, von, Eschenbach, Pa...
#                               ...
# 1065                                                   []
# 1066                                                   []
# 1067                  [(Deutschlands), (Thüringer, Wald)]
# 1068                                     [(Neil, Gaiman)]
# 1069    [(A, Close, and, Distant, Reading, of, Shakesp...
# Name: ner_text, Length: 1070, dtype: object

# %%
for t in df['title_normalized']:
    for w in snlp(t).ents:
        print(w.label_)
# Out:
# MISC
# MISC
# MISC
# MISC
# MISC
# MISC
# PER
# MISC
# PER
# PER
# MISC
# MISC
# MISC
# LOC
# LOC
# PER
# PER
# MISC
# ORG
# ORG
# MISC
# MISC
# MISC
# MISC
# LOC
# MISC
# MISC
# PER
# MISC
# PER
# MISC
# LOC
# LOC
# LOC
# PER
# PER
# PER
# LOC
# LOC
# PER
# LOC
# MISC
# PER
# PER
# PER
# LOC
# MISC
# MISC
# MISC
# MISC
# PER
# MISC
# MISC
# MISC
# PER
# PER
# PER
# PER
# MISC
# PER
# PER
# LOC
# PER
# MISC
# PER
# LOC
# MISC
# MISC
# ORG
# MISC
# MISC
# LOC
# MISC
# MISC
# MISC
# PER
# PER
# MISC
# MISC
# MISC
# MISC
# LOC
# MISC
# MISC
# LOC
# MISC
# MISC
# LOC
# LOC
# ORG
# MISC
# ORG
# MISC
# MISC
# MISC
# MISC
# MISC
# MISC
# MISC
# MISC
# PER
# PER
# MISC
# LOC
# MISC
# MISC
# PER
# PER
# MISC
# MISC
# PER
# PER
# PER
# PER
# MISC
# PER
# PER
# MISC
# LOC
# PER
# LOC
# PER
# MISC
# LOC
# MISC
# PER
# PER
# PER
# PER
# PER
# ORG
# MISC
# MISC
# MISC
# LOC
# MISC
# PER
# PER
# MISC
# PER
# PER
# PER
# PER
# MISC
# LOC
# MISC
# LOC
# MISC
# PER
# MISC
# LOC
# MISC
# PER
# PER
# MISC
# LOC
# LOC
# MISC
# MISC
# MISC
# MISC
# LOC
# PER
# MISC
# MISC
# MISC
# MISC
# MISC
# PER
# PER
# MISC
# MISC
# PER
# PER
# PER
# MISC
# LOC
# LOC
# PER
# PER
# PER
# LOC
# MISC
# PER
# LOC
# MISC
# PER
# LOC
# LOC
# LOC
# PER
# MISC
# MISC
# MISC
# ORG
# ORG
# ORG
# LOC
# MISC
# MISC
# PER
# MISC
# PER
# ORG
# LOC
# PER
# PER
# MISC
# MISC
# LOC
# MISC
# PER
# MISC
# PER
# MISC
# MISC
# PER
# MISC
# PER
# MISC
# PER
# PER
# PER
# PER
# MISC
# MISC
# LOC
# MISC
# LOC
# PER
# LOC
# MISC
# MISC
# MISC
# PER
# ORG
# PER
# PER
# PER
# PER
# PER
# PER
# PER
# PER
# PER
# LOC
# MISC
# ORG
# MISC
# PER
# PER
# PER
# MISC
# PER
# LOC
# PER
# PER
# PER
# PER
# MISC
# MISC
# PER
# ORG
# MISC
# PER
# LOC
# PER
# MISC
# PER
# PER
# PER
# LOC
# PER
# PER
# ORG
# PER
# MISC
# ORG
# MISC
# MISC
# MISC
# LOC
# MISC
# PER
# PER
# ORG
# PER
# LOC
# ORG
# ORG
# MISC
# MISC
# PER
# MISC
# MISC
# PER
# PER
# MISC
# MISC
# MISC
# PER
# PER
# PER
# LOC
# PER
# PER
# PER
# PER
# MISC
# PER
# PER
# PER
# LOC
# MISC
# ORG
# PER
# MISC
# MISC
# PER
# MISC
# MISC
# PER
# MISC
# PER
# MISC
# PER
# PER
# MISC
# PER
# ORG
# MISC
# PER
# PER
# MISC
# PER
# PER
# MISC
# LOC
# MISC
# PER
# ORG
# ORG
# PER
# PER
# PER
# MISC
# MISC
# LOC
# PER
# PER
# PER
# PER
# MISC
# MISC
# MISC
# PER
# PER
# PER
# MISC
# MISC
# PER
# PER
# MISC
# MISC
# LOC
# PER
# PER
# PER
# MISC
# ORG
# PER
# PER
# MISC
# PER
# ORG
# MISC
# PER
# PER
# MISC
# PER
# LOC
# LOC
# PER
# MISC
# PER
# PER
# MISC
# MISC
# PER
# PER
# PER
# ORG
# PER
# PER
# PER
# PER
# MISC
# LOC
# MISC
# MISC
# MISC
# PER
# ORG
# MISC
# MISC
# MISC
# MISC
# MISC
# LOC
# PER
# PER
# MISC
# MISC
# PER
# MISC
# PER
# PER
# ORG
# MISC
# MISC
# MISC
# PER
# MISC
# PER
# PER
# PER
# PER
# PER
# PER
# MISC
# MISC
# MISC
# MISC
# PER
# PER
# LOC
# PER
# PER
# PER
# MISC
# MISC
# PER
# MISC
# PER
# PER
# MISC
# PER
# PER
# MISC
# PER
# PER
# PER
# PER
# PER
# MISC
# PER
# PER
# MISC
# MISC
# MISC
# MISC
# PER
# MISC
# PER
# PER
# MISC
# PER
# PER
# PER
# LOC
# MISC
# MISC
# MISC
# PER
# MISC
# MISC
# PER
# PER
# MISC
# PER
# PER
# MISC
# MISC
# PER
# MISC
# LOC
# LOC
# ORG
# PER
# MISC
# PER
# LOC
# PER
# LOC
# PER
# LOC
# PER
# LOC
# PER
# MISC
# MISC
# MISC
# MISC
# PER
# MISC
# LOC
# LOC
# MISC
# MISC
# PER
# LOC
# LOC
# PER
# MISC
# MISC
# ORG
# MISC
# MISC
# PER
# MISC
# ORG
# MISC
# LOC
# LOC
# PER
# PER
# MISC
# MISC
# LOC
# MISC
# ORG
# ORG
# MISC
# PER
# MISC
# PER
# MISC
# PER
# PER
# PER
# PER
# PER
# LOC
# LOC
# MISC
# PER
# MISC
# PER
# ORG
# MISC
# PER
# LOC
# MISC
# MISC
# ORG
# PER
# PER
# MISC
# ORG
# PER
# PER
# PER
# PER
# MISC
# PER
# MISC
# PER
# MISC
# MISC
# PER
# PER
# MISC
# LOC
# PER
# PER
# PER
# MISC
# LOC
# ORG
# MISC
# ORG
# ORG
# ORG
# LOC
# LOC
# PER
# PER
# MISC
# LOC
# MISC
# MISC
# ORG
# LOC
# LOC
# LOC
# LOC
# MISC
# LOC
# MISC
# PER
# MISC
# ORG
# PER
# MISC
# ORG
# ORG
# PER
# MISC
# ORG
# ORG
# MISC
# PER
# PER
# PER
# MISC
# PER
# MISC
# PER
# PER
# LOC
# LOC
# PER
# PER
# PER
# PER
# PER
# PER
# PER
# MISC
# ORG
# MISC
# MISC
# MISC
# ORG
# PER
# LOC
# MISC
# ORG
# MISC
# ORG
# MISC
# MISC
# PER
# ORG
# PER
# PER
# PER
# MISC
# MISC
# MISC
# PER
# PER
# MISC
# LOC
# PER
# PER
# MISC
# MISC
# PER
# MISC
# PER
# LOC
# LOC
# LOC
# PER
# MISC

# %% [markdown]
# ## Step 5. Filtering NER Labels
# So say you're only interested in getting entities that are persons, you could run the following line:

# %%
df['persons']= df['title_normalized'].map(lambda x: [x for x in snlp(x).ents if x.label_ == "PER"])
# Out:
# 0                                                      []
# 1                                                      []
# 2                               [(Christopher, J., Koch)]
# 3                                                      []
# 4       [(gerbet, han), (Wolframs, von, Eschenbach, Pa...
#                               ...
# 1065                                                   []
# 1066                                                   []
# 1067                                                   []
# 1068                                     [(Neil, Gaiman)]
# 1069                                                   []
# Name: persons, Length: 1070, dtype: object

# %%
outfilename = 'ner_'+infilename
df.to_csv(outfilename)

# %%
pip install spacy-transformers
# Out:
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.1.4-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 KB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: transformers<4.16.0,>=3.4.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy-transformers) (4.12.3)
# Requirement already satisfied: spacy<4.0.0,>=3.1.3 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy-transformers) (3.1.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy-transformers) (2.4.2)
# Requirement already satisfied: torch>=1.6.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy-transformers) (1.10.0)
# Collecting spacy-alignments<1.0.0,>=0.7.2
#   Downloading spacy_alignments-0.8.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.1 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.4.0)
# Requirement already satisfied: jinja2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.11.3)
# Requirement already satisfied: setuptools in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (58.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.25.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.7.5)
# Requirement already satisfied: numpy>=1.15.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.20.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (8.0.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (20.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.6.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.6)
# Requirement already satisfied: typing-extensions in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from torch>=1.6.0->spacy-transformers) (4.1.1)
# Requirement already satisfied: filelock in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from transformers<4.16.0,>=3.4.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from transformers<4.16.0,>=3.4.0->spacy-transformers) (2021.4.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from transformers<4.16.0,>=3.4.0->spacy-transformers) (0.1.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from transformers<4.16.0,>=3.4.0->spacy-transformers) (0.10.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from transformers<4.16.0,>=3.4.0->spacy-transformers) (5.4.1)
# Requirement already satisfied: sacremoses in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from transformers<4.16.0,>=3.4.0->spacy-transformers) (0.0.46)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<4.0.0,>=3.1.3->spacy-transformers) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (1.26.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<4.0.0,>=3.1.3->spacy-transformers) (1.1.1)
# Requirement already satisfied: joblib in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers<4.16.0,>=3.4.0->spacy-transformers) (1.0.1)
# Requirement already satisfied: six in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from sacremoses->transformers<4.16.0,>=3.4.0->spacy-transformers) (1.16.0)
# Installing collected packages: spacy-alignments, spacy-transformers
# Successfully installed spacy-alignments-0.8.4 spacy-transformers-1.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_trf_bertbaseuncased_lg
# Out:
# ✘ No compatible package found for 'en_trf_bertbaseuncased_lg' (spaCy
# v3.2.2)

# %% [markdown]
# ## Suggested citation
# If you use this notebook as part of your project workflow, you can cite it with something to the effect of:
#
# Dombrowski, Quinn. *Named entity recognition in CSVs* Jupyter notebook. https://github.com/quinnanya/csv-ner. 2019.
