# %% [markdown]
# # Named entity recognition in CSVs
#
# This notebook uses [Spacy](https://spacy.io/) to perform named-entity recognition on text in specified columns of a CSV file. The notebook adds new columns to the CSV with the identified entities.
# It is 90% based on this wonderful notebook: https://github.com/quinnanya/csv-ner/blob/master/named-entity-recognition-in-csvs.ipynb. Only step 5 is new :)

# %% [markdown]
# ## Step 1. Load core modules

# %%
#os is used to change the directory
import os
#spacy is used for the NER
import spacy
#pandas is used to read, edit, and write tabular data
import pandas as pd

# %% [markdown]
# ## Step 2. Download and load language-specific data
# This notebook was originally created for German text, but you can substitute values in the following two cells with the corresponding ones for [another language that Spacy supports](https://spacy.io/models). Choose the language you'd like, and check the box for "import as module" on the Spacy site to see the values for the language you'd like to use.
#
# For instance, to use Lithuanian, you'd change the first code cell below to: `!python -m spacy download lt_core_news_sm`
#
# and the second one to:
#
# `import lt_core_news_sm
# snlp = spacy.load("import lt_core_news_sm")`
#
# After you've run the first code cell once ever on the computer where you're running this notebook, you can skip it and just run the cell that imports the module. There's no harm in running the first cell again, but it won't do anything.

# %%
#downloads the model for the specified language (English)
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 3.7 MB/s
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.1.0) (3.1.4)
# Requirement already satisfied: numpy>=1.15.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.20.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.59.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.1)
# Requirement already satisfied: packaging>=20.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (20.9)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.25.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: setuptools in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (58.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.6)
# Requirement already satisfied: jinja2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.11.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.0.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/silviaegt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.1.1)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/silviaegt/anaconda3/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#imports the model as a module
import en_core_web_sm
#loads the model as snlp
snlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Step 3. Specify file directory and file
# Replace `/Users/qad/Documents/netzdg` with the full path to the directory that has your input CSV file. This is also the directory where your output CSV file will be saved.
#
# The syntax for the path is different on Mac and Windows. For instance, the default path to the Documents directory is (substituting your user name on the computer for YOUR-USER-NAME):
#
# - On Mac: '/Users/YOUR-USER-NAME/Documents'
# - On Windows: 'C:\\\Users\\\YOUR-USER-NAME\\\Documents'
#
# Then, replace `netzdg_blog.csv` with the name of a CSV file in the directory you've specified. The first row of the CSV file should be a header (i.e. with the name of each column).

# %%
sourcefiledirectory = '/home/silviaegt/Documents/alemania_test/'
#changes the working directory to the directory specified above
os.chdir(sourcefiledirectory)
infilename = 'EThOS_CSV_202109.csv'

# %% [markdown]
# ## Step 4. Reading CSV, performing NER
# This step actually processes your data.
#
# In this example, there are two columns in the source file that contain text where we want to find entities: *text* and *comments*.
#
# The cell below reads in the data from the CSV file you've specified above. It creates two new columns: *ner_text* which includes the entities extracted from the *title_normalized* column (you can change the name).
#
# The `print(df['ner_text'])` command is optional, but are a convenient way for you to get a sense of what the output will be. When the values are printed, each term is surrounded by parentheses (), and all the entities for a given row of the CSV are surrounded by square brackets \[\]. When you *print* the output, multi-word entities are separated by commas within the parentheses (such as: (Europäische, Union)), but when you *write* it to a new CSV file, the parentheses and commas between individual words disappear, and you'll just get a single comma-separated list inside of square brackets, with commas representing individual entities (e.g. \[Uploadfilter, Europäische Union\]).

# %%
#creates pandas dataframe with your specified input file, using the first row as a header
df = pd.read_csv(infilename, header=0, low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d35ac8983a47> in <module>
#       1 #creates pandas dataframe with your specified input file, using the first row as a header
#       2 df = pd.read_csv(infilename, header=0, low_memory=False)
# ----> 3 head(df)
#
# NameError: name 'head' is not defined

# %%
df = df[df['Title'].str.contains("Language")]

# %%
#creates a new column, ner_text, with entities extracted from a column titled 'text'
df['ner_text'] = df['Abstract'].astype(str).apply(lambda x: list(snlp(x).ents))
#prints the values from ner_text
print(df['ner_text'])
# Out:
# 3485                                                     []
# 4550                                                     []
# 5781      [(Webster), (1986), (Campbell, ,, Burden, &, W...
# 5980                                                     []
# 6492                                                     []
#                                 ...
# 582400    [(Online, Community, Projects), (English), (a,...
# 582694    [(Saudi, Arabia), (G20), (2016), (2030), (Engl...
# 582972              [(first), (two), (four), (1), (2), (3)]
# 583480    [(Ghanaian, Sign, Language), (three), (GSL), (...
# 584221          [(Critical, Language, Awareness), (Kuwait)]
# Name: ner_text, Length: 654, dtype: object

# %%
for t in df['Title']:
    for w in snlp(t).ents:
        print(w.label_)
# Out:
# PERSON
# LANGUAGE
# LANGUAGE
# PERSON
# ORDINAL
# LANGUAGE
# NORP
# LANGUAGE
# DATE
# NORP
# LANGUAGE
# PERSON
# ORG
# GPE
# PERSON
# GPE
# GPE
# ORDINAL
# GPE
# PERSON
# PERSON
# NORP
# GPE
# ORG
# CARDINAL
# PRODUCT
# DATE
# EVENT
# ORG
# DATE
# GPE
# GPE
# ORG
# PERSON
# LAW
# NORP
# GPE
# DATE
# GPE
# PERSON
# GPE
# NORP
# GPE
# ORG
# ORG
# PERSON
# NORP
# ORG
# NORP
# NORP
# FAC
# LANGUAGE
# LOC
# LOC
# PERSON
# ORG
# ORG
# GPE
# LOC
# PERSON
# PERSON
# GPE
# DATE
# PERSON
# PERSON
# PERSON
# WORK_OF_ART
# DATE
# PERSON
# PERSON
# LANGUAGE
# LANGUAGE
# NORP
# LOC
# GPE
# DATE
# ORG
# PERSON
# PERSON
# GPE
# ORG
# GPE
# WORK_OF_ART
# NORP
# PERSON
# NORP
# GPE
# LANGUAGE
# ORDINAL
# PERSON
# GPE
# EVENT
# PERSON
# ORG
# NORP
# NORP
# LANGUAGE
# LANGUAGE
# LOC
# GPE
# CARDINAL
# CARDINAL
# NORP
# NORP
# ORG
# ORG
# GPE
# DATE
# NORP
# GPE
# NORP
# GPE
# LANGUAGE
# LANGUAGE
# DATE
# ORG
# ORDINAL
# NORP
# GPE
# GPE
# GPE
# NORP
# NORP
# NORP
# LANGUAGE
# LOC
# GPE
# PERSON
# GPE
# EVENT
# LANGUAGE
# GPE
# ORG
# CARDINAL
# CARDINAL
# DATE
# LANGUAGE
# ORDINAL
# GPE
# ORG
# NORP
# ORG
# GPE
# ORG
# PERSON
# PERSON
# PERSON
# GPE
# PERSON
# PERSON
# LOC
# GPE
# ORDINAL
# GPE
# NORP
# LANGUAGE
# ORG
# NORP
# LANGUAGE
# LOC
# ORG
# ORG
# GPE
# CARDINAL
# LANGUAGE
# GPE
# PERSON
# LANGUAGE
# CARDINAL
# GPE
# ORG
# GPE
# ORG
# LOC
# NORP
# LANGUAGE
# DATE
# PERSON
# GPE
# NORP
# NORP
# CARDINAL
# NORP
# GPE
# GPE
# GPE
# NORP
# PERSON
# ORG
# LANGUAGE
# EVENT
# GPE
# ORG
# LOC
# NORP
# ORG
# GPE
# GPE
# GPE
# NORP
# LANGUAGE
# DATE
# GPE
# EVENT
# NORP
# NORP
# CARDINAL
# PERSON
# PERSON
# DATE
# ORG
# ORG
# GPE
# LANGUAGE
# NORP
# GPE
# ORG
# LANGUAGE
# ORG
# CARDINAL
# LOC
# GPE
# GPE
# NORP
# NORP
# EVENT
# GPE
# ORG
# LOC
# PRODUCT
# GPE
# ORG
# EVENT
# PERSON
# WORK_OF_ART
# PERSON
# ORG
# ORG
# GPE
# NORP
# CARDINAL
# PERSON
# WORK_OF_ART
# PERSON
# DATE
# NORP
# PERSON
# CARDINAL
# ORG
# GPE
# PERSON
# ORG
# PERSON
# ORG
# PERSON
# ORG
# ORG
# ORG
# ORG
# NORP
# NORP
# NORP
# NORP
# ORG
# NORP
# LANGUAGE
# DATE
# ORG
# PERSON
# ORG
# NORP
# NORP
# LANGUAGE
# PERSON
# ORG
# GPE
# LANGUAGE
# ORG
# PERSON
# ORG
# GPE
# ORG
# ORG
# GPE
# ORG
# WORK_OF_ART
# PERSON
# DATE
# ORG
# WORK_OF_ART
# GPE
# GPE
# GPE
# ORG
# EVENT
# GPE
# LAW
# NORP
# ORG
# NORP
# DATE
# GPE
# DATE
# ORG
# ORG
# PERSON
# GPE
# NORP
# GPE
# ORG
# GPE
# LOC
# NORP
# NORP
# NORP
# GPE
# ORG
# NORP
# NORP
# NORP
# ORG
# ORG
# ORG
# GPE
# CARDINAL
# ORG
# LOC
# ORG
# WORK_OF_ART
# ORG
# ORG
# WORK_OF_ART
# GPE
# GPE
# PERSON
# NORP
# WORK_OF_ART
# NORP
# ORG
# GPE
# GPE
# NORP
# PERSON
# ORG
# PERSON
# PERSON
# ORG
# GPE
# GPE
# WORK_OF_ART
# WORK_OF_ART
# DATE
# LOC
# ORG
# GPE
# EVENT
# ORG
# LOC
# GPE
# ORG
# EVENT
# ORG
# NORP
# GPE
# GPE
# LANGUAGE
# GPE
# GPE
# GPE
# LOC
# ORG
# NORP
# ORDINAL
# LANGUAGE
# NORP
# PERSON
# GPE
# ORG
# ORG
# LOC
# GPE
# ORG
# LANGUAGE
# GPE
# GPE
# GPE
# DATE
# ORG
# PERSON
# PERSON
# ORG
# ORG
# ORG
# GPE
# LOC
# NORP
# LANGUAGE
# LOC
# ORDINAL
# WORK_OF_ART
# ORG
# GPE
# ORG
# LANGUAGE
# ORDINAL
# GPE
# ORG
# NORP
# NORP
# LANGUAGE
# NORP
# PERSON
# GPE
# CARDINAL
# CARDINAL
# GPE
# PERSON
# ORG
# ORG
# ORG
# DATE
# NORP
# GPE
# PERSON
# DATE
# NORP
# NORP
# PERSON
# GPE
# GPE
# GPE
# GPE
# ORG
# GPE
# ORG
# PERSON
# GPE
# ORG
# NORP
# ORG
# GPE
# PERSON
# WORK_OF_ART
# GPE
# NORP
# DATE
# LOC
# GPE
# GPE
# NORP
# ORG
# GPE
# LANGUAGE
# LANGUAGE
# LOC
# GPE
# WORK_OF_ART
# ORG
# ORG
# ORG
# EVENT
# GPE
# ORG
# ORG
# GPE
# GPE
# ORDINAL
# NORP
# EVENT
# GPE
# GPE
# NORP
# LANGUAGE
# NORP
# GPE
# GPE
# GPE
# GPE
# GPE
# PERSON
# NORP
# ORG
# NORP
# LANGUAGE
# ORDINAL
# GPE
# LANGUAGE
# GPE
# ORG
# ORDINAL
# GPE
# ORG
# LANGUAGE
# DATE
# NORP
# NORP
# ORG
# NORP
# LANGUAGE
# NORP
# EVENT
# NORP
# ORG
# PERSON
# ORG
# NORP
# DATE
# ORDINAL
# LOC
# CARDINAL
# ORG
# FAC
# GPE
# GPE
# DATE
# ORG
# GPE
# LANGUAGE
# EVENT
# PERSON
# ORG
# NORP
# NORP
# EVENT
# LOC
# GPE
# ORG
# DATE
# PRODUCT
# PERSON
# LANGUAGE
# NORP
# DATE
# GPE
# EVENT
# DATE
# PERSON
# PERSON
# NORP
# PERSON
# DATE
# PERSON
# ORG
# DATE
# LOC
# LOC
# NORP
# GPE
# NORP
# GPE
# NORP
# LANGUAGE
# LOC
# PERSON
# ORG
# GPE
# LOC
# GPE
# DATE
# LOC
# NORP
# NORP
# ORG
# PERSON
# ORG
# ORDINAL
# NORP
# NORP
# LOC
# LANGUAGE
# GPE
# GPE
# NORP
# CARDINAL
# GPE
# NORP
# NORP
# GPE
# NORP
# LOC
# GPE
# ORG
# ORG
# DATE
# NORP
# GPE
# NORP
# LANGUAGE
# GPE
# ORDINAL
# ORG
# NORP
# ORG
# NORP
# LANGUAGE
# PERSON
# NORP
# EVENT
# NORP
# GPE
# LOC
# GPE
# WORK_OF_ART
# NORP
# NORP
# NORP
# GPE
# GPE
# GPE
# GPE
# LANGUAGE
# LOC
# PRODUCT
# LANGUAGE
# LOC
# ORG
# GPE
# NORP
# LANGUAGE
# NORP
# EVENT
# ORG
# GPE
# LANGUAGE
# LANGUAGE
# LOC
# NORP
# LANGUAGE
# LOC
# GPE
# LANGUAGE
# LOC
# NORP
# NORP
# NORP
# ORG
# ORG
# DATE
# LANGUAGE
# ORG
# LANGUAGE
# LOC
# NORP
# LANGUAGE
# ORG
# LANGUAGE
# LANGUAGE
# NORP
# LANGUAGE
# NORP
# LANGUAGE
# GPE
# NORP
# NORP
# ORG
# NORP
# ORG
# LANGUAGE
# NORP
# ORG
# ORG
# NORP
# LANGUAGE
# NORP
# ORG
# LANGUAGE
# NORP
# ORG
# CARDINAL
# PERSON
# PERSON
# LOC
# GPE
# LANGUAGE
# ORDINAL
# PRODUCT
# EVENT
# GPE
# LANGUAGE
# DATE
# ORG
# ORG
# LANGUAGE
# LOC
# FAC
# ORG
# ORG
# LANGUAGE
# EVENT
# ORG
# GPE
# EVENT
# ORG
# CARDINAL
# ORG
# GPE
# NORP
# LANGUAGE
# LOC
# NORP
# LANGUAGE
# NORP
# EVENT
# LOC
# NORP
# LANGUAGE
# LOC
# ORG
# CARDINAL
# ORG
# ORG
# ORG
# EVENT
# LOC
# NORP
# GPE
# PERSON
# NORP
# NORP
# CARDINAL
# GPE
# LANGUAGE
# GPE
# GPE
# GPE
# FAC
# LANGUAGE
# ORG
# GPE
# NORP
# LANGUAGE
# LOC
# DATE
# ORG
# EVENT
# ORG
# ORG
# EVENT
# GPE
# NORP
# GPE
# NORP
# GPE
# LANGUAGE
# LOC
# LANGUAGE
# ORG
# GPE
# DATE
# LANGUAGE
# EVENT
# LOC
# GPE
# LOC
# GPE
# NORP
# NORP
# GPE
# GPE
# GPE
# DATE
# LANGUAGE
# NORP
# GPE
# NORP
# NORP
# LANGUAGE
# LOC
# ORG
# NORP
# PERSON
# LANGUAGE
# ORDINAL
# LANGUAGE
# NORP
# GPE
# ORG
# PERSON
# PERSON
# PERSON
# LANGUAGE
# GPE
# ORG
# ORDINAL
# GPE
# NORP
# ORG
# GPE
# CARDINAL
# LANGUAGE
# GPE
# PERSON
# GPE
# NORP
# NORP
# GPE
# NORP
# GPE
# ORG
# GPE
# NORP
# GPE
# ORG
# WORK_OF_ART
# PERSON
# ORG
# LANGUAGE
# LOC
# GPE
# ORG
# ORG
# ORG
# ORG
# LOC
# GPE
# CARDINAL
# ORG
# NORP
# ORG
# LANGUAGE
# NORP
# LANGUAGE
# ORDINAL
# GPE
# LANGUAGE
# PRODUCT
# LANGUAGE
# GPE
# GPE
# ORG
# DATE
# GPE
# NORP
# DATE
# LANGUAGE
# GPE
# ORG
# EVENT
# ORG
# ORG
# GPE
# ORG
# GPE
# GPE
# GPE
# GPE
# NORP
# LANGUAGE
# LOC
# NORP
# CARDINAL
# ORG
# GPE
# LANGUAGE
# ORG
# GPE
# ORG
# ORG
# GPE
# WORK_OF_ART
# LANGUAGE
# ORG
# ORG
# ORG
# PERSON
# NORP
# GPE
# GPE
# GPE
# DATE
# ORG
# EVENT
# ORG
# GPE
# GPE
# GPE
# GPE
# LANGUAGE
# ORG
# GPE
# ORG
# GPE
# PERSON
# GPE
# GPE
# LOC
# NORP
# NORP
# GPE
# GPE
# NORP
# GPE
# GPE
# GPE
# GPE
# GPE
# GPE
# GPE
# LOC
# GPE
# LANGUAGE
# NORP
# PERSON
# NORP
# LOC
# CARDINAL
# LOC
# NORP
# PERSON
# LANGUAGE
# LOC
# LOC
# GPE
# LOC
# ORG
# ORG
# LANGUAGE
# LOC
# NORP
# GPE
# LANGUAGE
# LANGUAGE
# LOC
# GPE
# LOC
# GPE
# GPE
# ORG
# PERSON
# LOC
# NORP
# LOC
# ORG
# GPE
# LANGUAGE
# NORP
# ORG
# NORP
# LOC
# LOC
# ORG

# %% [markdown]
# ## Step 5. Filtering NER Labels
# So say you're only interested in getting entities that are persons, you could run the following line:

# %%
df['persons']= df['Abstract'].map(lambda x: [x for x in snlp(x).ents if x.label_ == "PERSON"])

# %%
df['persons']
# Out:
# 3485                                                  []
# 4550                                                  []
# 5781      [(Webster), (Pattison), (Jensema), (Baddeley)]
# 5980                                                  []
# 6492                                                  []
#                                ...
# 582400                                                []
# 582694                                                []
# 582972                                                []
# 583480                                                []
# 584221                                                []
# Name: persons, Length: 654, dtype: object

# %%
outfilename = 'nerabstract_'+infilename
df.to_csv(outfilename)

# %% [markdown]
# ## Suggested citation
# If you use this notebook as part of your project workflow, you can cite it with something to the effect of:
#
# Dombrowski, Quinn. *Named entity recognition in CSVs* Jupyter notebook. https://github.com/quinnanya/csv-ner. 2019.
